# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # Opening Dataset

# %%
print(os.listdir())
# Out:
# ['.android', '.conda', '.condarc', '.idlerc', '.ipynb_checkpoints', '.ipython', '.jupyter', '.matplotlib', '.spyder-py3', '.thumbnails', '3D Objects', 'Anaconda3', 'AppData', 'Application Data', 'Cleaning data.ipynb', 'Complete-Python-3-Bootcamp-master', 'Contacts', 'Cookies', 'Currency converter.ipynb', 'Documents', 'Downloads', 'Dropbox', 'Favorites', 'Google Drive', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'MJKJRegInfo_U5E664P45VMUH7KFFLV36NSWUTVWJHRR', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TM.blf', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{53b39e88-18c4-11ea-a811-000d3aa4692b}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'OS', 'PhotoshopPortable', 'Pictures', 'PrintHood', 'Recent', 'Roaming', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'tmdb-movies.csv', 'Udem
# ...

# %%
df = pd.read_csv("tmdb-movies.csv")

# %%
df
# Out:
#            id    imdb_id  popularity     budget     revenue  \
# 0      135397  tt0369610   32.985763  150000000  1513528810
# 1       76341  tt1392190   28.419936  150000000   378436354
# 2      262500  tt2908446   13.112507  110000000   295238201
# 3      140607  tt2488496   11.173104  200000000  2068178225
# 4      168259  tt2820852    9.335014  190000000  1506249360
# ...       ...        ...         ...        ...         ...
# 10861      21  tt0060371    0.080598          0           0
# 10862   20379  tt0060472    0.065543          0           0
# 10863   39768  tt0060161    0.065141          0           0
# 10864   21449  tt0061177    0.064317          0           0
# 10865   22293  tt0060666    0.035919      19000           0
#
#                      original_title  \
# 0                    Jurassic World
# 1                Mad Max: Fury Road
# 2                         Insurgent
# 3      Star Wars: The Force Awakens
# 4                         Furious 7
# ...

# %% [markdown]
# # Third highest and third lowest budget

# %%
df.columns
# Out:
# Index(['id', 'imdb_id', 'popularity', 'budget', 'revenue', 'original_title',
#        'cast', 'homepage', 'director', 'tagline', 'keywords', 'overview',
#        'runtime', 'genres', 'production_companies', 'release_date',
#        'vote_count', 'vote_average', 'release_year', 'budget_adj',
#        'revenue_adj'],
#       dtype='object')

# %%
df = df[['budget' , 'original_title' , 'release_year' , 'genres' , 'cast' , 'revenue' , 'runtime']]

# %%
df
# Out:
#           budget                original_title  release_year  \
# 0      150000000                Jurassic World          2015
# 1      150000000            Mad Max: Fury Road          2015
# 2      110000000                     Insurgent          2015
# 3      200000000  Star Wars: The Force Awakens          2015
# 4      190000000                     Furious 7          2015
# ...          ...                           ...           ...
# 10861          0            The Endless Summer          1966
# 10862          0                    Grand Prix          1966
# 10863          0           Beregis Avtomobilya          1966
# 10864          0        What's Up, Tiger Lily?          1966
# 10865      19000      Manos: The Hands of Fate          1966
#
#                                           genres  \
# 0      Action|Adventure|Science Fiction|Thriller
# 1      Action|Adventure|Science Fiction|Thriller
# 2             Adventure|Science Fiction|Thriller
# ...

# %% [markdown]
# # Sorting budget column

# %%
sorted_budget_df = df.sort_values(by = 'budget')

# %%
sorted_budget_df
# Out:
#          budget                                  original_title  release_year  \
# 5361          0                                 The Butcher Boy          1997
# 5959          0                                   Muscle Shoals          2013
# 5958          0  Lego Batman: The Movie - DC Super Heroes Unite          2013
# 5957          0        We Steal Secrets: The Story of WikiLeaks          2013
# 5955          0                                    Get a Horse!          2013
# ...         ...                                             ...           ...
# 6570  270000000                                Superman Returns          2006
# 14    280000000                         Avengers: Age of Ultron          2015
# 7387  300000000        Pirates of the Caribbean: At World's End          2007
# 3375  380000000     Pirates of the Caribbean: On Stranger Tides          2011
# 2244  425000000                               The Warrior's Way          2010
#
# ...

# %%
sorted_budget_df_nonempty = sorted_budget_df[sorted_budget_df['budget']>0]

# %%
sorted_budget_df_nonempty
# Out:
#          budget                               original_title  release_year  \
# 3065          1           Angus, Thongs and Perfect Snogging          2008
# 1151          1                                  Fear Clinic          2014
# 2618          1                                 Lost & Found          1999
# 3581          1                      Love, Wedding, Marriage          2011
# 8944          2                                 Death Wish 2          1982
# ...         ...                                          ...           ...
# 6570  270000000                             Superman Returns          2006
# 14    280000000                      Avengers: Age of Ultron          2015
# 7387  300000000     Pirates of the Caribbean: At World's End          2007
# 3375  380000000  Pirates of the Caribbean: On Stranger Tides          2011
# 2244  425000000                            The Warrior's Way          2010
#
#                                          genres  \
# ...

# %% [markdown]
# # Third lowest budget

# %%
sorted_budget_df_nonempty.head()
# Out:
#       budget                      original_title  release_year  \
# 3065       1  Angus, Thongs and Perfect Snogging          2008
# 1151       1                         Fear Clinic          2014
# 2618       1                        Lost & Found          1999
# 3581       1             Love, Wedding, Marriage          2011
# 8944       2                        Death Wish 2          1982
#
#                            genres  \
# 3065  Comedy|Drama|Family|Romance
# 1151                       Horror
# 2618               Comedy|Romance
# 3581               Comedy|Romance
# 8944        Action|Crime|Thriller
#
#                                                    cast  revenue  runtime
# 3065  Georgia Groome|Eleanor Tomlinson|Aaron Taylor-...        0      100
# 1151  Thomas Dekker|Robert Englund|Cleopatra Coleman...        0       95
# 2618  David Spade|Sophie Marceau|Ever Carradine|Step...      100       95
# 3581  Mandy Moore|Kellan Lutz|Jessica Szohr|Autumn F...     1378       90
# ...

# %% [markdown]
# # Third highest budget

# %%
sorted_budget_df_nonempty.tail()
# Out:
#          budget                               original_title  release_year  \
# 6570  270000000                             Superman Returns          2006
# 14    280000000                      Avengers: Age of Ultron          2015
# 7387  300000000     Pirates of the Caribbean: At World's End          2007
# 3375  380000000  Pirates of the Caribbean: On Stranger Tides          2011
# 2244  425000000                            The Warrior's Way          2010
#
#                                          genres  \
# 6570   Adventure|Fantasy|Action|Science Fiction
# 14             Action|Adventure|Science Fiction
# 7387                   Adventure|Fantasy|Action
# 3375                   Adventure|Action|Fantasy
# 2244  Adventure|Fantasy|Action|Western|Thriller
#
#                                                    cast     revenue  runtime
# 6570  Brandon Routh|Kevin Spacey|Kate Bosworth|James...   391081192      154
# ...
